# %%
import tensorflow as tf
import numpy as np 
import cv2
import os

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
image_dir = 'flowers/'
categories = ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
for category in categories:
    path = os.path.join(image_dir, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img))
        plt.imshow(img_array)
        break

# %%
categories.index('rose')
# Out:
# 2

# %%
def create_dataset(img_size = 100):
    
    training_data = []
    
    
    for category in categories:
        path = os.path.join(image_dir, category)
        img_class = categories.index(category)
    
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img))
                img_array = cv2.resize(img_array, (img_size, img_size))

                training_data.append([img_array, img_class])
            except Exception as e:
                print(e)
                
    return np.array(training_data)

# %%
training_data = create_dataset()
# Out:
# OpenCV(3.4.2) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
np.random.shuffle(training_data)

# %%
def plot_image(training_data, label):
    plt_imgs = 9
    
    fig, axes = plt.subplots(3, 3, figsize = (9,9))
    
    for i, ax in enumerate(axes.flat):
        ax.imshow(training_data[i])
        
        xlabel = categories[np.argmax(label[i])]
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])
        
    plt.show()

# %%
X = training_data[:,0]
y = training_data[:,1]

# %%
def one_hot(num_class, class_num):
    return np.eye(num_class)[class_num]

# %%
test_y = []
for i in range(len(y)):
    test_y.append(y[i])

# %%
test_x = []
for i in range(len(X)):
    test_x.append(X[i])

# %%
y = np.array(test_y)
y = one_hot(np.max(y)+1, y)

# %%
X = np.array(test_x)/255

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
plot_image(X_train, y_train)

# %%
def next_batch(x, y, batch_size = 64):
    index = np.random.choice(len(x), size = batch_size)
    batch_x = x[index]
    batch_y = y[index]
    return batch_x, batch_y

# %%
# tensorflow

# placeholder
input_x = tf.placeholder(tf.float32, shape = [None, 100, 100, 3], name = 'input_image')
y_true = tf.placeholder(tf.float32, shape = [None, 5], name = 'y_true')

# weights, 第一层
weights_conv_1 = tf.Variable(tf.truncated_normal(shape = [5, 5, 3, 32], stddev = 0.1))
bias_1 = tf.Variable(tf.truncated_normal(shape = [32], stddev = 0.1))

# 第一层卷积层
conv_layer_first = tf.nn.conv2d(input_x, filter = weights_conv_1, strides = [1, 1, 1, 1], padding = 'VALID')
conv_layer_first = tf.nn.relu(conv_layer_first) + bias_1
max_pool_1 = tf.nn.max_pool(conv_layer_first, ksize = [1,2,2,1], strides = [1, 2, 2, 1], padding = 'VALID')

# %%
max_pool_1.shape
# Out:
# TensorShape([Dimension(None), Dimension(48), Dimension(48), Dimension(32)])

# %%
# weights, 第二层
weights_conv_2 = tf.Variable(tf.truncated_normal(shape = [5, 5, 32, 64], stddev = 0.1))
bias_2 = tf.Variable(tf.truncated_normal(shape = [64], stddev = 0.1))

# 第二层卷积层
conv_layer_second = tf.nn.conv2d(max_pool_1, weights_conv_2, strides = [1, 1, 1, 1], padding = 'VALID')
conv_layer_second = tf.nn.relu(conv_layer_second) + bias_2
max_pool_2 = tf.nn.max_pool(conv_layer_second, ksize = [1,2,2,1], strides = [1,2,2,1], padding = 'VALID')

# %%
max_pool_2.shape
# Out:
# TensorShape([Dimension(None), Dimension(22), Dimension(22), Dimension(64)])

# %%
'''
# weights, 第三层
weights_conv_3 = tf.Variable(tf.truncated_normal(shape = [8, 8, 64, 128], stddev = 0.1))
bias_3 = tf.Variable(tf.truncated_normal(shape = [128], stddev = 0.1))

# 第三层卷积层
conv_layer_third = tf.nn.conv2d(max_pool_2, weights_conv_3, strides = [1, 1, 1, 1], padding = 'VALID')
conv_layer_third = tf.nn.relu(conv_layer_third) + bias_3
max_pool_3 = tf.nn.max_pool(conv_layer_third, ksize = [1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
'''
# Out:
# "\n# weights, 第三层\nweights_conv_3 = tf.Variable(tf.truncated_normal(shape = [8, 8, 64, 128], stddev = 0.1))\nbias_3 = tf.Variable(tf.truncated_normal(shape = [128], stddev = 0.1))\n\n# 第三层卷积层\nconv_layer_third = tf.nn.conv2d(max_pool_2, weights_conv_3, strides = [1, 1, 1, 1], padding = 'VALID')\nconv_layer_third = tf.nn.relu(conv_layer_third) + bias_3\nmax_pool_3 = tf.nn.max_pool(conv_layer_third, ksize = [1,2,2,1], strides = [1,2,2,1], padding = 'VALID')\n"

# %%
max_pool_2.shape
# Out:
# TensorShape([Dimension(None), Dimension(22), Dimension(22), Dimension(64)])

# %%
# weights, 全连接层1
weights_flatten_1 = tf.Variable(tf.truncated_normal(shape = [22*22*64, 32], stddev = 0.1))
bias_flatten_1 = tf.Variable(tf.truncated_normal(shape = [32], stddev = 0.1))

# 全连接层1
flatten_x = tf.reshape(max_pool_2, (-1, 22*22*64))
flatten_1 = tf.matmul(flatten_x, weights_flatten_1)
flatten_1 = tf.nn.relu(flatten_1) + bias_flatten_1

# weights, 全连接层2
weights_flatten_2 = tf.Variable(tf.truncated_normal(shape = [32, 5], stddev = 0.1))
bias_flatten_2 = tf.Variable(tf.truncated_normal(shape = [5], stddev = 0.1))

# output
flatten_2 = tf.matmul(flatten_1, weights_flatten_2) + bias_flatten_2
y_pred = tf.nn.softmax(flatten_2)

# %%
y_pred.shape
# Out:
# TensorShape([Dimension(None), Dimension(5)])

# %%
# loss function

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels = y_true, logits = y_pred))
train = tf.train.AdamOptimizer(learning_rate = 1e-4).minimize(loss)

# %%
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    
    for i in range(5000):
        batch_x, batch_y = next_batch(X_train, y_train)
        sess.run(train, feed_dict = {input_x: batch_x, y_true: batch_y})
        
        if i % 10 == 0:
            matches = tf.equal(tf.argmax(y_pred,1),tf.argmax(y_true,1))
            acc = tf.reduce_mean(tf.cast(matches,tf.float32))
            
            print('Current step: ', i)
            print(sess.run(acc, feed_dict = {input_x: X_test, y_true: y_test}))
# Out:
# Current step:  0
# 0.16647398
# Current step:  10
# 0.22543353
# Current step:  20
# 0.28901735
# Current step:  30
# 0.33063585
# Current step:  40
# 0.35144508
# Current step:  50
# 0.40346822
# Current step:  60
# 0.41271678
# Current step:  70
# 0.42543352
# Current step:  80
# 0.4312139
# Current step:  90
# 0.45086706
# Current step:  100
# 0.4485549
# Current step:  110
# 0.46127167
# Current step:  120
# 0.46242774
# Current step:  130
# 0.49364161
# Current step:  140
# 0.47976878
# Current step:  150
# 0.49595377
# Current step:  160
# 0.50404626
# Current step:  170
# 0.48208094
# Current step:  180
# 0.50289017
# Current step:  190
# 0.5086705
# Current step:  200
# 0.50289017
# Current step:  210
# 0.48901734
# Current step:  220
# 0.5017341
# Current step:  230
# 0.49364161
# Current step:  240
# 0.51445085
# Current step:  250
# 0.4982659
# Current step:  260
# 0.51560694
# Current step:  270
# 0.51098263
# Current step:  280
# 0.51098263
# Current step:  290
# 0.53410405
# Current step:  300
# 0.48439306
# Current step:  310
# 0.5213873
# Current step:  320
# 0.53294796
# Current step:  330
# 0.5132948
# Current step:  340
# 0.51907516
# Current step:  350
# 0.5364162
# Current step:  360
# 0.50057805
# Current step:  370
# 0.53410405
# Current step:  380
# 0.53294796
# Current step:  390
# 0.53410405
# Current step:  400
# 0.55144507
# Current step:  410
# 0.5456647
# Current step:  420
# 0.55260116
# Current step:  430
# 0.5271676
# Current step:  440
# 0.5433526
# Current step:  450
# 0.55260116
# Current step:  460
# 0.55260116
# Current step:  470
# 0.5410405
# Current step:  480
# 0.5260116
# Current step:  490
# 0.5630058
# Current step:  500
# 0.55028903
# Current step:  510
# 0.5549133
# Current step:  520
# 0.56647396
# Current step:  530
# 0.5549133
# Current step:  540
# 0.5618497
# Current step:  550
# 0.5595376
# Current step:  560
# 0.56763005
# Current step:  570
# 0.56763005
# Current step:  580
# 0.55144507
# Current step:  590
# 0.57225436
# Current step:  600
# 0.56878614
# Current step:  610
# 0.56878614
# Current step:  620
# 0.5653179
# Current step:  630
# 0.5445087
# Current step:  640
# 0.5618497
# Current step:  650
# 0.56416184
# Current step:  660
# 0.5630058
# Current step:  670
# 0.55144507
# Current step:  680
# 0.56647396
# Current step:  690
# 0.58381504
# Current step:  700
# 0.5849711
# Current step:  710
# 0.56647396
# Current step:  720
# 0.5757225
# Current step:  730
# 0.5745665
# Current step:  740
# 0.5618497
# Current step:  750
# 0.57919073
# Current step:  760
# 0.5699422
# Current step:  770
# 0.57109827
# Current step:  780
# 0.57919073
# Current step:  790
# 0.5549133
# Current step:  800
# 0.5595376
# Current step:  810
# 0.56763005
# Current step:  820
# 0.56878614
# Current step:  830
# 0.5699422
# Current step:  840
# 0.5699422
# Current step:  850
# 0.5757225
# Current step:  860
# 0.5699422
# Current step:  870
# 0.5595376
# Current step:  880
# 0.5757225
# Current step:  890
# 0.5815029
# Current step:  900
# 0.5780347
# Current step:  910
# 0.5768786
# Current step:  920
# 0.58381504
# Current step:  930
# 0.5803468
# Current step:  940
# 0.57225436
# Current step:  950
# 0.58612716
# Current step:  960
# 0.5757225
# Current step:  970
# 0.57919073
# Current step:  980
# 0.56878614
# Current step:  990
# 0.5618497
# Current step:  1000
# 0.5734104
# Current step:  1010
# 0.5757225
# Current step:  1020
# 0.5618497
# Current step:  1030
# 0.57919073
# Current step:  1040
# 0.5630058
# Current step:  1050
# 0.5757225
# Current step:  1060
# 0.5734104
# Current step:  1070
# 0.5606936
# Current step:  1080
# 0.5757225
# Current step:  1090
# 0.5768786
# Current step:  1100
# 0.5815029
# Current step:  1110
# 0.5757225
# Current step:  1120
# 0.5780347
# Current step:  1130
# 0.5884393
# Current step:  1140
# 0.5930636
# Current step:  1150
# 0.57919073
# Current step:  1160
# 0.57919073
# Current step:  1170
# 0.5803468
# Current step:  1180
# 0.5734104
# Current step:  1190
# 0.58381504
# Current step:  1200
# 0.5606936
# Current step:  1210
# 0.5803468
# Current step:  1220
# 0.5699422
# Current step:  1230
# 0.5653179
# Current step:  1240
# 0.5653179
# Current step:  1250
# 0.5768786
# Current step:  1260
# 0.57109827
# Current step:  1270
# 0.5734104
# Current step:  1280
# 0.56763005
# Current step:  1290
# 0.5653179
# Current step:  1300
# 0.5768786
# Current step:  1310
# 0.5699422
# Current step:  1320
# 0.57109827
# Current step:  1330
# 0.5734104
# Current step:  1340
# 0.5803468
# Current step:  1350
# 0.57919073
# Current step:  1360
# 0.5849711
# Current step:  1370
# 0.57109827
# Current step:  1380
# 0.5768786
# Current step:  1390
# 0.5884393
# Current step:  1400
# 0.56878614
# Current step:  1410
# 0.57109827
# Current step:  1420
# 0.5780347
# Current step:  1430
# 0.5699422
# Current step:  1440
# 0.5803468
# Current step:  1450
# 0.58381504
# Current step:  1460
# 0.5815029
# Current step:  1470
# 0.5699422
# Current step:  1480
# 0.5895954
# Current step:  1490
# 0.5884393
# Current step:  1500
# 0.5757225
# Current step:  1510
# 0.56647396
# Current step:  1520
# 0.56763005
# Current step:  1530
# 0.58265895
# Current step:  1540
# 0.58381504
# Current step:  1550
# 0.5734104
# Current step:  1560
# 0.5815029
# Current step:  1570
# 0.5699422
# Current step:  1580
# 0.5815029
# Current step:  1590
# 0.5745665
# Current step:  1600
# 0.5768786
# Current step:  1610
# 0.5815029
# Current step:  1620
# 0.57109827
# Current step:  1630
# 0.5815029
# Current step:  1640
# 0.5757225
# Current step:  1650
# 0.5768786
# Current step:  1660
# 0.56647396
# Current step:  1670
# 0.5745665
# Current step:  1680
# 0.5803468
# Current step:  1690
# 0.59075147
# Current step:  1700
# 0.5895954
# Current step:  1710
# 0.5849711
# Current step:  1720
# 0.5884393
# Current step:  1730
# 0.5930636
# Current step:  1740
# 0.5803468
# Current step:  1750
# 0.5757225
# Current step:  1760
# 0.58265895
# Current step:  1770
# 0.58381504
# Current step:  1780
# 0.5884393
# Current step:  1790
# 0.5849711
# Current step:  1800
# 0.58381504
# Current step:  1810
# 0.58381504
# Current step:  1820
# 0.57919073
# Current step:  1830
# 0.58381504
# Current step:  1840
# 0.5734104
# Current step:  1850
# 0.5803468
# Current step:  1860
# 0.5780347
# Current step:  1870
# 0.58612716
# Current step:  1880
# 0.5618497
# Current step:  1890
# 0.58265895
# Current step:  1900
# 0.58381504
# Current step:  1910
# 0.5734104
# Current step:  1920
# 0.5768786
# Current step:  1930
# 0.58265895
# Current step:  1940
# 0.5815029
# Current step:  1950
# 0.5919075
# Current step:  1960
# 0.5849711
# Current step:  1970
# 0.5780347
# Current step:  1980
# 0.5919075
# Current step:  1990
# 0.5815029
# Current step:  2000
# 0.5757225
# Current step:  2010
# 0.56878614
# Current step:  2020
# 0.5849711
# Current step:  2030
# 0.58381504
# Current step:  2040
# 0.58265895
# Current step:  2050
# 0.57919073
# Current step:  2060
# 0.57919073
# Current step:  2070
# 0.59075147
# Current step:  2080
# 0.5745665
# Current step:  2090
# 0.5815029
# Current step:  2100
# 0.5780347
# Current step:  2110
# 0.5849711
# Current step:  2120
# 0.5630058
# Current step:  2130
# 0.5895954
# Current step:  2140
# 0.57919073
# Current step:  2150
# 0.58728325
# Current step:  2160
# 0.5757225
# Current step:  2170
# 0.5895954
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-a32c2c2ffc56> in <module>()
#       5     for i in range(5000):
#       6         batch_x, batch_y = next_batch(X_train, y_train)
# ----> 7         sess.run(train, feed_dict = {input_x: batch_x, y_true: batch_y})
#       8
#       9         if i % 10 == 0:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
